# %% [markdown]
# <a href="https://colab.research.google.com/github/buzihelp-source/ADVANCE-TXT-UPLOADER/blob/main/Copy_of_Untitled126.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import shutil

# Unzipping the repository
zip_path = '/content/v3-uploder-kesav-v2-fixed.zip'
extract_path = '/content/bot_repo'

if os.path.exists(extract_path):
    shutil.rmtree(extract_path)

import zipfile
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print(f'Extracted to {extract_path}')
# Out:
# Extracted to /content/bot_repo

# %%
# Setting up environment variables
os.environ['API_ID'] = '36123528'
os.environ['API_HASH'] = '7f77eb79febe2b7cf5d33d6d57bc8ac0'
os.environ['BOT_TOKEN'] = '8609138890:AAFrqzor4n3AOFqC53ouXdcl13CXpHsgBUk'
os.environ['DATABASE_URL'] = 'mongodb+srv://itsgoluAPI:jrMHSipToKUEnmcp@cpprivateapi.ghhp3oz.mongodb.net/?appName=CpprivateApi'
os.environ['OWNER_ID'] = '8532700793'

print('Environment variables set.')
# Out:
# Environment variables set.

# %%
# Installing dependencies
# %cd {extract_path}
# Find requirements.txt if it exists
import glob
req_files = glob.glob('**/requirements.txt', recursive=True)
if req_files:
    # !pip install -r {req_files[0]}
else:
    print('No requirements.txt found. Installing common libraries.')
    # !pip install pyrogram tgcrypto motor pymongo
# Out:
# /content/bot_repo
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.3/182.3 kB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.6/123.6 kB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 15.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 55.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 62.2 MB/s eta 0:00:00
# ...

# %%
# Attempting to run the bot
# We search for common entry points like main.py or bot.py
entry_points = glob.glob('**/main.py', recursive=True) + glob.glob('**/bot.py', recursive=True)
if entry_points:
    print(f'Starting bot using {entry_points[0]}...')
    # !python3 {entry_points[0]}
else:
    print('Could not find main.py or bot.py. Please check the file structure.')
# Out:
# Streaming output truncated to the last 5000 lines.
# [download]  32.2% of ~ 331.75MiB at   17.14MiB/s ETA 00:14 (frag 156/486)
# [download]  32.2% of ~ 332.63MiB at   17.14MiB/s ETA 00:14 (frag 156/486)
# [download]  32.2% of ~ 332.57MiB at   17.14MiB/s ETA 00:14 (frag 157/486)
# [download]  32.4% of ~ 330.95MiB at   17.14MiB/s ETA 00:14 (frag 157/486)
# [download]  32.3% of ~ 331.37MiB at   17.14MiB/s ETA 00:14 (frag 158/486)
# [download]  32.5% of ~ 329.39MiB at   17.14MiB/s ETA 00:14 (frag 159/486)
# [download]  32.8% of ~ 327.00MiB at   17.14MiB/s ETA 00:14 (frag 159/486)
# [download]  32.7% of ~ 327.20MiB at   17.14MiB/s ETA 00:14 (frag 160/486)
# [download]  32.8% of ~ 326.39MiB at   17.14MiB/s ETA 00:14 (frag 160/486)
# [download]  32.9% of ~ 326.30MiB at   17.51MiB/s ETA 00:13 (frag 160/486)
# [download]  32.9% of ~ 326.31MiB at   17.51MiB/s ETA 00:13 (frag 160/486)
# [download]  32.9% of ~ 326.31MiB at   17.51MiB/s ETA 00:13 (frag 160/486)
# ...
